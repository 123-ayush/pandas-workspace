# %% [markdown]
# Exploratory Data Analysis (EDA)
# - it is done to find patterns/relationships in data and structure of data.
# - also help in data cleaning (missing values, find outliers, any kind of potential bias)

# %% [markdown]
# Steps in EDA:
# - load and structure
# - clean data
# - statistical summaries
# - data visualization
